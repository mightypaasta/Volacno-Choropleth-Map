# %%
import folium

# %%
import pandas as pd

# %%
df1=pd.read_csv('./data-hut-starbucks-location-dataset/starbucks_2018_11_06.csv')
df1
# Out:
#                              name  \
# 0                            交易廣場
# 1                            德福廣場
# 2                           荷李活廣場
# 3                           機鐵香港站
# 4                            太古廣場
# ...                           ...
# 13613             Village Swindon
# 13614             Xuchang Nanyang
# 13615  Gothenburg Central Station
# 13616      Southside Marketplace.
# 13617      Wurzbach & NW Military
#
#                                                      url  \
# 0        https://www.starbucks.com/store-locator/store/6
# 1        https://www.starbucks.com/store-locator/store/8
# 2        https://www.starbucks.com/store-locator/store/1
# 3       https://www.starbucks.com/store-locator/store/13
# 4       https://www.starbucks.com/store-locator/store/17
# ...                                                  ...
# 13613  https://www.starbucks.com/store-locator/store/...
# 13614  https://www.starbucks.com/store-locator/store/...
# ...

# %%
map=folium.Map(location=[25.606390797877904, 85.15175855939738],zoom_start=3)
map.add_child(folium.Marker(location=[25.606390797877904,85.15175855939738],popup='This is my location',icon=folium.Icon(color='green')))
map.save('map1.html')

# %%
for i in range(df1['latitude'].size):
    map.add_child(folium.Marker(location=[df1['latitude'][i],df1['longitude'][i]],popup='Starbucks',icon=folium.Icon(color='green')))
map.save('map2.html')

# %%
from subprocess import run
from datetime import datetime
from threading import Timer

x=datetime.today()
# y=x.replace(day=x.day,hour=1,minute=4,second=0,microsecond=0)
# diff=y-x
# sec=x.second+1

def online():
    code=input('Enter the classroom code')
#     automata(code)

# def automata(code):
#     run('https://www.youtube.com/'+code)
      

Timer(2,online).start()
# Out:
# Enter the classroom code
# Exception in thread Thread-19:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 1254, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-78-123f72418a2c>", line 11, in online
# EOFError: EOF when reading a line

# %%
from threading import Timer
def hola():
    a=input('Enter the number')
    print(a)
    
Timer(1,hola).start()
Ti
print('This is before output')
# Out:
# This is before output
# Enter the number
# Exception in thread Thread-22:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 1254, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-81-7ef32fbb54a7>", line 3, in hola
# EOFError: EOF when reading a line

# %%
ls=['hello','mellow']
ls
# Out:
# ['hello', 'mellow']

# %%
import pandas as pd
import folium
import random
df
# Out:
#     VOLCANX020    NUMBER            NAME       LOCATION  \
# 0        509.0  1201-01=           Baker  US-Washington
# 1        511.0  1201-02-    Glacier Peak  US-Washington
# 2        513.0  1201-03-         Rainier  US-Washington
# 3        515.0  1201-05-      St. Helens  US-Washington
# 4        516.0  1201-04-           Adams  US-Washington
# ..         ...       ...             ...            ...
# 57       580.0  1210-03-  Valles Caldera  US-New Mexico
# 58       581.0  1209-02-   Sunset Crater     US-Arizona
# 59       584.0  1203-20-           Amboy  US-California
# 60       586.0  1210-02-    Zuni-Bandera  US-New Mexico
# 61       588.0  1210-01-       Carrizozo  US-New Mexico
#
#                    STATUS    ELEV             TYPE TIMEFRAME        LAT  \
# 0              Historical  3285.0  Stratovolcanoes        D3  48.776798
# 1        Tephrochronology  3213.0    Stratovolcano        D4  48.111801
# 2        Dendrochronology  4392.0    Stratovolcano        D3  46.869801
# ...

# %%
df=pd.read_csv('Volcanoes.csv')
vmap=folium.Map(location=[46.869801, -121.751000],zoom_start=5)
lat=list(df['LAT'])
lon=list(df['LON'])
name=list(df['NAME'])
height=list(df['ELEV'])
status=list(df['STATUS'])

html = """<h4>Volcano information:</h4>
Name: %s <br>
Height: %s <br>
Status: %s 
"""

colorList=['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue', 'darkpurple','pink', 'lightblue', 'lightgreen', 'gray', 'black', 'lightgray']
def randomColorPicker():
    return random.choice(colorList)

for la,ln,nm,ht,st in zip(lat,lon,name,height,status):
    iframe = folium.IFrame(html=html %  , width=200, height=100)
    vmap.add_child(folium.Marker(location=[la,ln],popup=folium.Popup(iframe),icon=folium.Icon(color=randomColorPicker())))
vmap.save('VolcanoMap.html')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-fc7a99f934e2> in <module>
#      18
#      19 for la,ln,nm,ht,st in zip(lat,lon,name,height,status):
# ---> 20     iframe = folium.IFrame(html=html % str(nm) %str(ht) %str(st) , width=200, height=100)
#      21     vmap.add_child(folium.Marker(location=[la,ln],popup=folium.Popup(iframe),icon=folium.Icon(color=randomColorPicker())))
#      22 vmap.save('VolcanoMap.html')
#
# TypeError: not enough arguments for format string
